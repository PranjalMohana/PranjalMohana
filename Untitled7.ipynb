# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.android', '.cache', '.conda', '.condarc', '.continuum', '.eclipse', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.p2', '.VirtualBox', '.vscode', '3D Objects', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'Favorites', 'IdeaProjects', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Raw_Skills_Dataset.csv', 'Recent', 'Saved Games', 'ScStore', 'Searches', 'SendTo', 'Start Menu', 'Sti_Trace.log', 'Telco-Customer-Churn.csv', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Videos', 'VirtualBox VMs']

# %%
df =pd.read_csv("Raw_Skills_Dataset.csv")

# %%
df
# Out:
#                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# RAW DATA    0
# dtype: int64

# %%
df.shape
# Out:
# (34116, 1)

# %%
df.describe()
# Out:
#        RAW DATA
# count     34116
# unique    15677
# top      Python
# freq        272

# %%
df.head
# Out:
# <bound method NDFrame.head of                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]>

# %%
    def plot_boxplot(df):
       
        plt.grid(False)
        plt.show()

# %%
plot_boxplot(df)

# %%
print(df.shape)
# Out:
# (34116, 1)

# %%
import seaborn as sb

# %%
df.sample(5)
# Out:
#                                                 RAW DATA
# 5626   automated data security and data governance be...
# 11434                                      methodologies
# 13268                                     QUALIFICATIONS
# 6214                                                EGSE
# 31906                                           Redshift

# %%
df.head
# Out:
# <bound method NDFrame.head of                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]>

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
# Out:
# <AxesSubplot:>

# %%
sns.displot(df['RAW DATA'])
plt.subplot(1,2,2)
plt.show()

# %%
df['RAW DATA'].describe()
# Out:
# count      34116
# unique     15677
# top       Python
# freq         272
# Name: RAW DATA, dtype: object

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]

# %%
df.drop_duplicates(subset='RAW DATA', keep=False)
# Out:
#                     RAW DATA
# 0                   What ifs
# 1                  seniority
# 4                    Lambdas
# 5               Java Streams
# 12                   MyBatis
# ...                      ...
# 34103  C / embedded software
# 34105        telecom product
# 34106   Leadership qualities
# 34108               Actalent
# 34109         all applicants
#
# [12355 rows x 1 columns]

# %%
df.drop_duplicates(subset='RAW DATA', keep=False, inplace=True)

# %%
df
# Out:
#                     RAW DATA
# 0                   What ifs
# 1                  seniority
# 4                    Lambdas
# 5               Java Streams
# 12                   MyBatis
# ...                      ...
# 34103  C / embedded software
# 34105        telecom product
# 34106   Leadership qualities
# 34108               Actalent
# 34109         all applicants
#
# [12355 rows x 1 columns]

# %%
import requests

# %%
import json

# %%
print(df)
# Out:
#                     RAW DATA
# 0                   What ifs
# 1                  seniority
# 4                    Lambdas
# 5               Java Streams
# 12                   MyBatis
# ...                      ...
# 34103  C / embedded software
# 34105        telecom product
# 34106   Leadership qualities
# 34108               Actalent
# 34109         all applicants
#
# [12355 rows x 1 columns]
